# %% [markdown]
# ## Introduccion a Python <br>
# Python es un lenguaje de **Programacion** de alto nivel, enfocado en la inteligencia artificial. <br>
# Tambien me permite generar Aplicaciones de escritorio, web, mobiles con programacion orientada a objetos. <br>
# **Programador** Steven Chuiza

# %%
# Aqui se escribe un comentario de una sola linea
print ("Hola esto es un mensaje")
# Out:
# Hola esto es un mensaje

# %%
print ("Steven Chuiza")
# Out:
# Steven Chuiza

# %% [markdown]
# https://github.com/tiven29/Python-2026/blob/main/introduccion.ipynb
