# %% [markdown]
# 1.- Escribe un programa que muestre por pantalla la concatenación de un número y una cadena de caracteres. Para obtener esta concatenación puedes usar uno de los operadores explicados en este tema. Ejemplo: dado el número 3 y la cadena ‘abc’, el programa mostrará la cadena‘3abc’.

# %%
numero = int(input("Ingresa un numero: "))
cadena = input("Ingresa una cadena de texto: ")

resultado = str (numero) + cadena
print ('La concatenacion es la siguiente: ', resultado)
# Out:
# Ingresa un numero:  8
# Ingresa una cadena de texto:  hellow
# La concatenacion es la siguiente:  8hellow

# %% [markdown]
# 2.- Escribe un programa que muestre por pantalla un valor booleano que indique si un número entero N está contenido en un intervalo semiabierto [a,b), el cual establece una cota inferior a (inclusive) y una cota superior b (exclusive) para N.

# %%
N = [ 'java', 'python', 'programacion', 'c++']
a = 'programacion'
b = 'visual_basic'

print (N)
print("El tamaño de la lista es:", len(N))

elemento = N.index(a)
print (b)

N[elemento] = b
print (N)
# Out:
# ['java', 'python', 'programacion', 'c++']
# El tamaño de la lista es: 4
# visual_basic
# ['java', 'python', 'visual_basic', 'c++']

# %% [markdown]
# 3.- Escribe un programa que, dado dos strings S1 y S2 y dos números enteros N1 y N2, determine si el substring que en S1 se extiende desde la posición N1 a la N2 (ambos inclusive) está contenido en S2.

# %%
S1 = 'Programacion con python'
S2 = 'Programacion lenguaje entre humano y computador'
N1 = 0
N2 = 12

substring = S1 [N1 : N2 + 1]
R = substring in S2

print (f'Substring extraido de S1: {substring}')
print (f'¿Esta {substring} contenido en S2? : {R}')
# Out:
# Substring extraido de S1: Programacion
# ¿Esta Programacion  contenido en S2? : True

# %% [markdown]
# 4.-Dada una lista con elementos duplicados, escribir un programa que muestre una nueva lista con el mismo contenido que la primera pero sin elementos duplicados.

# %%
L = [1,2,3,3,3,4,4,5,6,6,7,7]
print('Lista original:', L)

N = set(L)
print ('Nueva lista sin elementos duplicados', N)
# Out:
# Lista original: [1, 2, 3, 3, 3, 4, 4, 5, 6, 6, 7, 7]
# Nueva lista sin elementos duplicados {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# 5.- Escribe un programa que, dada una lista de strings L, un string s perteneciente a L y un string t, reemplace s por t en L. El programa debe mostrar la lista resultante por pantalla.

# %%
L = ['Manzana','Pera','Uva','Naranja','Piña','Sandias']
print ('Lista original: ', L)

S = L[3]
print ('String perteneciente a L: ', S)

ST = L.index(S)
print ('Indice asignado: ', ST)

T = 'Mango'
print (T)

L[ST] = T
print (L)
# Out:
# Lista original:  ['Manzana', 'Pera', 'Uva', 'Naranja', 'Piña', 'Sandias']
# String perteneciente a L:  Naranja
# Indice asignado:  3
# Mango
# ['Manzana', 'Pera', 'Uva', 'Mango', 'Piña', 'Sandias']

# %% [markdown]
# 6.- Escribe un programa que defina una tupla con elementos numéricos, reemplace el valor del último por un valor diferente y muestre la tupla por pantalla. Recuerda que las tuplas son inmutables. Tendrás que usar objetos intermedios.

# %%
L = (10,20,30,40,50)
Lista = list(L)
print (Lista)
Lista[-1] = int(input('Ingreser nuevo valor: '))
VF = tuple(Lista)
print ('Ultima tupla modificada a :', VF)
# Out:
# [10, 20, 30, 40, 50]
# Ingreser nuevo valor:  90
# Ultima tupla modificada a : (10, 20, 30, 40, 90)
